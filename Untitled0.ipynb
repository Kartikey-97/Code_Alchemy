# %% [markdown]
# <a href="https://colab.research.google.com/github/Kartikey-97/Code_Alchemy/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/train_1.zip -d /content/train_1

# %%
# !ls /content/train_1
# Out:
# __MACOSX  train_1

# %%
# !ls /content/train_1/train_1
# Out:
# train1	val1

# %%
# !ls /content/train_1/train_1/train1
# Out:
# images	labels

# %%
# %%writefile /content/data.yaml
# train: /content/train_1/train_1/train1/images
# val: /content/train_1/train_1/val1/images
#
# nc: 7
# names: [
#   'OxygenTank',
#   'NitrogenTank',
#   'FirstAidBox',
#   'FireAlarm',
#   'SafetySwitchPanel',
#   'EmergencyPhone',
#   'FireExtinguisher'
# ]
# Out:
# Writing /content/data.yaml

# %%
# !cat /content/data.yaml
# Out:
# train: /content/train_1/train_1/train1/images
# val: /content/train_1/train_1/val1/images
#
# nc: 7
# names: [
#   'OxygenTank',
#   'NitrogenTank',
#   'FirstAidBox',
#   'FireAlarm',
#   'SafetySwitchPanel',
#   'EmergencyPhone',
#   'FireExtinguisher'
# ]

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/data.yaml epochs=15 imgsz=640 batch=16 device=0 project=runs name=safety_fast
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 985, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 773, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
# ...

# %%
# !nvidia-smi
# Out:
# Wed Nov 12 13:06:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.2 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/data.yaml epochs=15 imgsz=640 batch=16 device=0 project=runs name=safety_fast
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %%writefile /content/data.yaml
# train: /content/train_1/train_1/train1/images
# val: /content/train_1/train_1/val1/images
#
# nc: 7
# names: [
#   'OxygenTank',
#   'NitrogenTank',
#   'FirstAidBox',
#   'FireAlarm',
#   'SafetySwitchPanel',
#   'EmergencyPhone',
#   'FireExtinguisher'
# ]
# Out:
# Writing /content/data.yaml

# %%
# !ls /content
# Out:
# data.yaml  runs  sample_data  yolov8n.pt

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/data.yaml epochs=15 imgsz=640 batch=16 device=0 project=runs name=safety_fast
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls -R /content/train_1 | head -50
# Out:
# ls: cannot access '/content/train_1': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/train_1.zip -d /content/train_1

# %%
# !ls /content/train_1
# Out:
# __MACOSX  train_1

# %%
# !ls /content/train_1/train_1
# Out:
# train1	val1

# %%
# !ls /content/train_1/train_1/train1/images | head -10
# Out:
# 000000000_light_cluttered.png
# 000000003_cluttered_room.png
# 000000003_light_cluttered.png
# 000000003_light_uncluttered.png
# 000000004_cluttered_hallway.png
# 000000006_light_cluttered.png
# 000000006_light_cluttered_room.png
# 000000008_cluttered_hallway.png
# 000000008_cluttered_room.png
# 000000009_light_cluttered_room.png

# %%
# !ls /content/train_1/train_1/val1/images | head -10
# Out:
# 000000000_vcluttered_hallway.png
# 000000001_vlight_cluttered_room.png
# 000000002_vlight_uncluttered.png
# 000000003_vlight_cluttered.png
# 000000004_vlight_cluttered.png
# 000000004_vlight_uncluttered.png
# 000000005_vcluttered_room.png
# 000000006_vlight_uncluttered.png
# 000000007_vlight_cluttered.png
# 000000007_vlight_uncluttered.png

# %%
# !ls /content/train_1/train_1/train1/labels | head -10
# Out:
# 000000000_light_cluttered.txt
# 000000003_cluttered_room.txt
# 000000003_light_cluttered.txt
# 000000003_light_uncluttered.txt
# 000000004_cluttered_hallway.txt
# 000000006_light_cluttered_room.txt
# 000000006_light_cluttered.txt
# 000000008_cluttered_hallway.txt
# 000000008_cluttered_room.txt
# 000000009_light_cluttered_room.txt

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/data.yaml epochs=15 imgsz=640 batch=16 device=0 project=runs name=safety_fast
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/test3.zip -d /content/test3

# %%
# !ls /content/drive/MyDrive/Hackathon_AI
# Out:
# ls: cannot access '/content/drive/MyDrive/Hackathon_AI': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -q /content/drive/MyDrive/test3.zip -d /content/test3
# Out:
# replace /content/test3/__MACOSX/._test3? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# !find /content/test3 -maxdepth 3 -type d -name images -print
# Out:
# /content/test3/test3/images
# /content/test3/__MACOSX/test3/images

# %%
# !yolo task=detect mode=predict \
  model=/content/runs/safety_fast3/weights/best.pt \
  source=/content/test3/test3/images \
  save=True \
  imgsz=640
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 955, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 81, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 149, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 288, in _load
#     self.model, self.ckpt = load_checkpoint(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1461, in load_checkpoint
# ...

# %%
# !find /content/drive -name best.pt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive
# Out:
#  4AECCBCF-EA17-4135-B948-5A13A623A1A7.jpeg
#  7D51C8B3-1319-4574-B496-1E0C56DE0E67.jpeg
#  Classroom
# 'Colab Notebooks'
# 'Copy of camVideo.mp4'
#  DF9E840B-B7F3-4919-ACED-23D4ED2B1DA5.jpeg
# 'image (1).jpg'
# 'image (2).jpg'
# 'image (3).jpg'
#  image.jpg
# 'Scanned Documents.pdf'
#  test3.zip
#  train_1.zip
# 'yea, but there are 7 different content slides: Ab....gsheet'

# %%
# !unzip -q /content/drive/MyDrive/train_1.zip -d /content/train_1

# %%
data_yaml = """
train: /content/train_1/train_1/train1/images
val: /content/train_1/train_1/val1/images

nc: 7
names: ['OxygenTank', 'NitrogenTank', 'FirstAidBox', 'FireAlarm', 'SafetySwitchPanel', 'EmergencyPhone', 'FireExtinguisher']
"""

with open('/content/data.yaml', 'w') as f:
    f.write(data_yaml)

# %%
# !yolo task=detect mode=train \
  model=yolov8n.pt \
  data=/content/data.yaml \
  epochs=15 \
  imgsz=640 \
  batch=16 \
  device=0 \
  project=runs \
  name=safety_final
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp /content/runs/safety_final/weights/best.pt /content/drive/MyDrive/best.pt

# %%
# !unzip -o -q /content/drive/MyDrive/test3.zip -d /content/test3

# %%
# !yolo task=detect mode=predict \
  model=/content/runs/safety_final/weights/best.pt \
  source=/content/test3/test3/images \
  save=True \
  imgsz=640
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1408 /content/test3/test3/images/000000000_light_unclutter.png: 384x640 1 SafetySwitchPanel, 1 EmergencyPhone, 70.9ms
# image 2/1408 /content/test3/test3/images/000000000_vdark_clutter.png: 384x640 1 FireExtinguisher, 6.5ms
# image 3/1408 /content/test3/test3/images/000000000_vlight_unclutter.png: 384x640 1 OxygenTank, 4 NitrogenTanks, 2 SafetySwitchPanels, 6.3ms
# image 4/1408 /content/test3/test3/images/000000001_dark_clutter.png: 384x640 1 OxygenTank, 6.2ms
# image 5/1408 /content/test3/test3/images/000000001_dark_unclutter.png: 384x640 1 FireAlarm, 1 EmergencyPhone, 6.2ms
# image 6/1408 /content/test3/test3/images/000000001_vlight_unclutter.png: 384x640 3 OxygenTanks, 4 NitrogenTanks, 6.1ms
# image 7/1408 /content/test3/test3/images/000000002_dark_unclutter.png: 384x640 1 FireExtinguisher, 6.5ms
# ...
